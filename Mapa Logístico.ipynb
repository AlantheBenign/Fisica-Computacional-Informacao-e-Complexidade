# %% [markdown]
# MAPA LOGÍSTICO

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
def mapa(x,r):
    res = r*x*(1-x)
    return res

# %%
limite = 51
n = np.arange(limite)

rs = [0.5,2.5,3.1,3.5,3.7]

fig, ((ax0, ax1), (ax2, ax3), (ax4, ax5)) = plt.subplots(3, 2,figsize=(12, 12))
fig.suptitle('x = 0.5')

for j in range(5):
    x = 0.5
    xs = np.array([])
    xs = np.append(xs,x)
    for i in range(limite-1):
        x = mapa(x,rs[j])
        xs = np.append(xs,x)
        
    if j==0:
        ax0.plot(n,xs,label='r = ' + str(rs[j]))
        ax1.plot(n,xs,label='r = ' + str(rs[j]))
    elif j==1:
        ax2.plot(n,xs,label='r = ' + str(rs[j]))
    elif j==2:
        ax3.plot(n,xs,label='r = ' + str(rs[j]))
    elif j==3:
        ax4.plot(n,xs,label='r = ' + str(rs[j]))
    elif j==4:
        ax5.plot(n,xs,label='r = ' + str(rs[j]))

for ax in fig.get_axes():
    ax.label_outer()
    ax.legend()

# %% [markdown]
# Aqui percebemos que as populações convergem para um valor na situação de equilíbrio ou oscilam entre alguns (ou vários) valores conforme as gerações se passam.

# %%
limite = 51
n = np.arange(limite)

rs = [0.5,2.5,3.1,3.5,3.7]
x0s = [0.5,0.25,0.75]

fig, ((ax0, ax1), (ax2, ax3), (ax4, ax5)) = plt.subplots(3, 2,figsize=(12, 12))
fig.suptitle('x = 0.25, 0.50, 0.75')

for j in range(5):
    plt.figure()
    for k in range(3):
        x = x0s[k]
        xs = np.array([])
        xs = np.append(xs,x)
        for i in range(limite-1):
            x = mapa(x,rs[j])
            xs = np.append(xs,x)
        if j==0:
            ax0.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
            ax1.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==1:
            ax2.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==2:
            ax3.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==3:
            ax4.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==4:
            ax5.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))

for ax in fig.get_axes():
    ax.label_outer()
    ax.legend(loc=4)

# %% [markdown]
# Aqui percebemos que para populações iniciais bastante distintas o comportamento dessas populações não é muito alterado conforme as gerações avançam.

# %% [raw]
# limite = 51
# n = np.arange(limite)
#
# rs = [0.5,2.5,3.1,3.5,3.7]
#
# for j in range(5):
#     x = 0.25
#     xs = []
#     xs = np.array(xs)
#     xs = np.append(xs,x)
#     for i in range(limite-1):
#         x = mapa(x,rs[j])
#         xs = np.append(xs,x)
#
#     plt.figure()
#     plt.plot(n,xs,label='r = ' + str(rs[j]))
#     plt.legend()
#     plt.show()

# %% [raw]
# limite = 51
# n = np.arange(limite)
#
# rs = [0.5,2.5,3.1,3.5,3.7]
#
# for j in range(5):
#     x = 0.75
#     xs = []
#     xs = np.array(xs)
#     xs = np.append(xs,x)
#     for i in range(limite-1):
#         x = mapa(x,rs[j])
#         xs = np.append(xs,x)
#
#     plt.figure()
#     plt.plot(n,xs,label='r = ' + str(rs[j]))
#     plt.legend()
#     plt.show()

# %%
limite = 51
n = np.arange(limite)

rs = [0.5,2.5,3.1,3.5,3.7]
x0s = [0.5,0.501,0.5001]

fig, ((ax0, ax1), (ax2, ax3), (ax4, ax5)) = plt.subplots(3, 2,figsize=(12, 12))
fig.suptitle('x = 0.5000, 0.5010, 0.5001')

for j in range(5):
    for k in range(3):
        x = x0s[k]
        xs = np.array([])
        xs = np.append(xs,x)
        for i in range(limite-1):
            x = mapa(x,rs[j])
            xs = np.append(xs,x)

        if j==0:
            ax0.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
            ax1.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==1:
            ax2.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==2:
            ax3.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==3:
            ax4.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==4:
            ax5.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))

for ax in fig.get_axes():
    ax.label_outer()
    ax.legend(loc=4)

# %% [markdown]
# Já nesse caso, de forma até contra intuitiva, pequeníssimas alterações na população inicial resultam em grandes divergências entre os comportamentos de diferentes populações para r = 3.7, mas não para os outros valores de r. Um comportamento semelhante pode ser observado nos próximos gráficos.

# %%
limite = 51
n = np.arange(limite)

rs = [0.5,2.5,3.1,3.5,3.7]
x0s = [0.25,0.251,0.2501]

fig, ((ax0, ax1), (ax2, ax3), (ax4, ax5)) = plt.subplots(3, 2,figsize=(12, 12))
fig.suptitle('x = 0.2500, 0.2510, 0.2501')

for j in range(5):
    for k in range(3):
        x = x0s[k]

        xs = np.array([])
        xs = np.append(xs,x)
        for i in range(limite-1):
            x = mapa(x,rs[j])
            xs = np.append(xs,x)

        if j==0:
            ax0.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
            ax1.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==1:
            ax2.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==2:
            ax3.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==3:
            ax4.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==4:
            ax5.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))

for ax in fig.get_axes():
    ax.label_outer()
    ax.legend(loc=4)

# %%
limite = 51
n = np.arange(limite)

rs = [0.5,2.5,3.1,3.5,3.7]
x0s = [0.75,0.751,0.7501]

fig, ((ax0, ax1), (ax2, ax3), (ax4, ax5)) = plt.subplots(3, 2,figsize=(12, 12))
fig.suptitle('x = 0.7500, 0.7510, 0.7501')

for j in range(5):
    for k in range(3):
        x = x0s[k]
        xs = np.array([])
        xs = np.append(xs,x)
        for i in range(limite-1):
            x = mapa(x,rs[j])
            xs = np.append(xs,x)

        if j==0:
            ax0.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
            ax1.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==1:
            ax2.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==2:
            ax3.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==3:
            ax4.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))
        elif j==4:
            ax5.plot(n,xs,label='r = ' + str(rs[j]) + ' , x0 = ' + str(x0s[k]))

for ax in fig.get_axes():
    ax.label_outer()
    ax.legend(loc=4)

# %%
limite = 1000
pontos_por_r = 100
divisoes = 2500
poucos = 200

rs = np.linspace(0,3,poucos)
rs = np.append(rs,np.linspace(3,4,divisoes))
xss = np.array([])
rss = np.array([])

for j in rs:
    x = 0.5
    clear_output(wait=True)
    print(str("%.2f" % ((j/4)*100))+"%", end="\n")
    for i in range(limite):
        x = mapa(x,j)
        if i >= (limite - pontos_por_r - 1):
            rss = np.append(rss,j)
            xss = np.append(xss,x)

xss = np.reshape(xss,(divisoes+poucos,pontos_por_r + 1))
rss = np.reshape(rss,(divisoes+poucos,pontos_por_r + 1))
# Out:
# 100.00%

# %%
plt.figure()
for i in range(divisoes+poucos):
    plt.plot(rss[i],xss[i],'bo',markersize=0.5)
plt.show()

# %% [markdown]
# O gráfico acima mostra os valores que as populações assumem após várias gerações:
#
# Para valores de r < 1, as populações se extinguem;
#
# Para 1 < r < 3, as populações convergem para um único valor estável;
#
# Para 3 < r < ~3.4, as populações ocilam entre dois valores possíveis;
#
# Para a maioria dos demais intervalos as populações oscilam entre inúmeros valores de forma caótica;

# %%
plt.figure()
for i in range(divisoes+poucos):
    if 3.7 <= rss[i][0] <= 3.9:
        plt.plot(rss[i],xss[i],'bo',markersize=0.5)
plt.show()

# %% [markdown]
# Aqui percebemos que existem comporamentos diferentes dentro da região caótica.

# %%
plt.figure()
for i in range(divisoes+poucos):
    if 3.840 <= rss[i][0] <= 3.856:
        plt.plot(rss[i],xss[i],'bo',markersize=0.5)
plt.ylim((0.425,0.575))
plt.show()

# %% [markdown]
# Para este intervalo de r, o comportamento é semelhante ai da curva como um todo, mostrando seu comportamento fractal.
